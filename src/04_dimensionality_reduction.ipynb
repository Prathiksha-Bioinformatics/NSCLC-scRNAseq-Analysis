# %%
import scanpy as sc 
import matplotlib.pyplot as plt 
sc.settings.figdir ="../results/figures"

# %%
adata = sc.read_h5ad('../data/processed/preprocessed.h5ad')

# %%
#pca
sc.tl.pca(adata,svd_solver='arpack')

# %%
#visualization 
sc.pl.pca_variance_ratio(adata,log=True,save='_pca_variance_ratio.png')
# Out:
# WARNING: saving figure to file ../results/figures/pca_variance_ratio_pca_variance_ratio.png

# %%
#check pca for technical effects 

sc.pl.pca(adata,color=['total_counts','pct_counts_mt'],save='_technical_effects.png')
# Out:
# WARNING: saving figure to file ../results/figures/pca_technical_effects.png

# %%
#build neighbor graph 
sc.pp.neighbors(adata,n_neighbors=15,n_pcs=30 )

# %%
#compute umap 
sc.tl.umap(adata)

# %%
#visualize umap 
sc.pl.umap(adata,save='_umap.png')
# Out:
# WARNING: saving figure to file ../results/figures/umap_umap.png

# %%
#visualize and probe 
sc.pl.umap(adata,color=['total_counts','sample'],save='_umap_totalcounts_sample.png')
# Out:
# WARNING: saving figure to file ../results/figures/umap_umap_totalcounts_sample.png

# %%
adata.obs
# Out:
#                                index        title      sample  \
# 0             AAACCTGAGAAACCGC_LN_05        LN_05  GSM3827151
# 2          AAACCTGAGAAGGTGA_LUNG_N18     LUNG_N18  GSM3827118
# 3          AAACCTGAGACAAAGG_LUNG_N18     LUNG_N18  GSM3827118
# 4             AAACCTGAGACATAAC_LN_04        LN_04  GSM3827150
# 5          AAACCTGAGACCTTTG_LUNG_N30     LUNG_N30  GSM3827122
# ...                              ...          ...         ...
# 208501     TTTGTCATCTTGCCGT_LUNG_T30     LUNG_T30  GSM3827133
# 208502  TTTGTCATCTTGTATC_EFFUSION_13  EFFUSION_13  GSM3827160
# 208503     TTTGTCATCTTTACAC_LUNG_N20     LUNG_N20  GSM3827120
# 208504     TTTGTCATCTTTACAC_LUNG_T25     LUNG_T25  GSM3827131
# 208505     TTTGTCATCTTTAGGG_LUNG_T31     LUNG_T31  GSM3827134
#
#                        status submission_date last_update_date type  \
# 0       Public on Mar 27 2020     May 29 2019      Aug 18 2021  SRA
# 2       Public on Mar 27 2020     May 29 2019      Aug 02 2022  SRA
# ...

# %%
adata.write('../data/processed/reduced.h5ad')
