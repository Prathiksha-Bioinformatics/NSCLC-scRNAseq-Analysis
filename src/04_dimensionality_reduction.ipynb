# %%
import scanpy as sc 
import matplotlib.pyplot as plt 
sc.settings.figdir ="../results/figures"

# %%
adata = sc.read_h5ad('../data/processed/preprocessed.h5ad')

# %%
#pca
sc.tl.pca(adata,svd_solver='arpack')

# %%
#visualization 
sc.pl.pca_variance_ratio(adata,log=True,save='_pca_variance_ratio.png')
# Out:
# WARNING: saving figure to file ../results/figures/pca_variance_ratio_pca_variance_ratio.png

# %%
#check pca for technical effects 

sc.pl.pca(adata,color=['total_counts','pct_counts_mt'],save='_technical_effects.png')
# Out:
# WARNING: saving figure to file ../results/figures/pca_technical_effects.png

# %%
#build neighbor graph 
sc.pp.neighbors(adata,n_neighbors=15,n_pcs=30 )

# %%
#compute umap 
sc.tl.umap(adata)

# %%
#visualize umap 
sc.pl.umap(adata,save='_umap.png')
# Out:
# WARNING: saving figure to file ../results/figures/umap_umap.png

# %%
#visualize and probe 
sc.pl.umap(adata,color=['total_counts'],save='_umap_totalcounts_sample.png')
# Out:
# WARNING: saving figure to file ../results/figures/umap_umap_totalcounts_sample.png

# %%
adata.obs
# Out:
#                               n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCTGAGAAACCGC_LN_05                     1690                 7.433075
# AAACCTGAGAAGGTGA_LUNG_N18                  1113                 7.015712
# AAACCTGAGACAAAGG_LUNG_N18                  1100                 7.003974
# AAACCTGAGACATAAC_LN_04                      948                 6.855409
# AAACCTGAGACCTTTG_LUNG_N30                   847                 6.742881
# ...                                         ...                      ...
# TTTGTCATCTTGCCGT_LUNG_T30                  2245                 7.716906
# TTTGTCATCTTGTATC_EFFUSION_13               1199                 7.090077
# TTTGTCATCTTTACAC_LUNG_N20                   834                 6.727432
# TTTGTCATCTTTACAC_LUNG_T25                   921                 6.826545
# TTTGTCATCTTTAGGG_LUNG_T31                  5768                 8.660254
#
#                               total_counts  log1p_total_counts  \
# AAACCTGAGAAACCGC_LN_05             19928.0            9.899931
# AAACCTGAGAAGGTGA_LUNG_N18           3214.0            8.075583
# AAACCTGAGACAAAGG_LUNG_N18           2990.0            8.003363
# AAACCTGAGACATAAC_LN_04              3880.0            8.263848
# AAACCTGAGACCTTTG_LUNG_N30           2565.0            7.850103
# ...                                    ...                 ...
# TTTGTCATCTTGCCGT_LUNG_T30           7981.0            8.984944
# TTTGTCATCTTGTATC_EFFUSION_13        4113.0            8.322151
# TTTGTCATCTTTACAC_LUNG_N20           1979.0            7.590852
# TTTGTCATCTTTACAC_LUNG_T25           3342.0            8.114624
# TTTGTCATCTTTAGGG_LUNG_T31          27366.0           10.217093
#
#                               pct_counts_in_top_50_genes  \
# AAACCTGAGAAACCGC_LN_05                         84.017463
# AAACCTGAGAAGGTGA_LUNG_N18                      37.678905
# AAACCTGAGACAAAGG_LUNG_N18                      36.254181
# AAACCTGAGACATAAC_LN_04                         53.427835
# AAACCTGAGACCTTTG_LUNG_N30                      48.304094
# ...                                                  ...
# TTTGTCATCTTGCCGT_LUNG_T30                      41.360732
# TTTGTCATCTTGTATC_EFFUSION_13                   46.146365
# TTTGTCATCTTTACAC_LUNG_N20                      38.706417
# TTTGTCATCTTTACAC_LUNG_T25                      49.670856
# TTTGTCATCTTTAGGG_LUNG_T31                      29.660893
#
#                               pct_counts_in_top_100_genes  \
# AAACCTGAGAAACCGC_LN_05                          87.354476
# AAACCTGAGAAGGTGA_LUNG_N18                       53.453640
# AAACCTGAGACAAAGG_LUNG_N18                       51.471572
# AAACCTGAGACATAAC_LN_04                          69.948454
# AAACCTGAGACCTTTG_LUNG_N30                       63.235867
# ...                                                   ...
# TTTGTCATCTTGCCGT_LUNG_T30                       50.582634
# TTTGTCATCTTGTATC_EFFUSION_13                    61.876975
# TTTGTCATCTTTACAC_LUNG_N20                       52.956038
# TTTGTCATCTTTACAC_LUNG_T25                       66.277678
# TTTGTCATCTTTAGGG_LUNG_T31                       37.542936
#
#                               pct_counts_in_top_200_genes  \
# AAACCTGAGAAACCGC_LN_05                          90.074267
# AAACCTGAGAAGGTGA_LUNG_N18                       66.677038
# AAACCTGAGACAAAGG_LUNG_N18                       64.949833
# AAACCTGAGACATAAC_LN_04                          79.046392
# AAACCTGAGACCTTTG_LUNG_N30                       73.684211
# ...                                                   ...
# TTTGTCATCTTGCCGT_LUNG_T30                       60.593911
# TTTGTCATCTTGTATC_EFFUSION_13                    72.380258
# TTTGTCATCTTTACAC_LUNG_N20                       65.891865
# TTTGTCATCTTTACAC_LUNG_T25                       76.810293
# TTTGTCATCTTTAGGG_LUNG_T31                       46.861068
#
#                               pct_counts_in_top_500_genes  total_counts_mt  \
# AAACCTGAGAAACCGC_LN_05                          93.692292             43.0
# AAACCTGAGAAGGTGA_LUNG_N18                       80.927194            106.0
# AAACCTGAGACAAAGG_LUNG_N18                       79.933110            133.0
# AAACCTGAGACATAAC_LN_04                          88.453608             76.0
# AAACCTGAGACCTTTG_LUNG_N30                       86.471735            113.0
# ...                                                   ...              ...
# TTTGTCATCTTGCCGT_LUNG_T30                       73.925573            198.0
# TTTGTCATCTTGTATC_EFFUSION_13                    83.005106            114.0
# TTTGTCATCTTTACAC_LUNG_N20                       83.122789             97.0
# TTTGTCATCTTTACAC_LUNG_T25                       87.402753             94.0
# TTTGTCATCTTTAGGG_LUNG_T31                       59.731053           2572.0
#
#                               log1p_total_counts_mt  pct_counts_mt  n_genes
# AAACCTGAGAAACCGC_LN_05                     3.784190       0.215777     1690
# AAACCTGAGAAGGTGA_LUNG_N18                  4.672829       3.298071     1113
# AAACCTGAGACAAAGG_LUNG_N18                  4.897840       4.448161     1100
# AAACCTGAGACATAAC_LN_04                     4.343805       1.958763      948
# AAACCTGAGACCTTTG_LUNG_N30                  4.736198       4.405458      847
# ...                                             ...            ...      ...
# TTTGTCATCTTGCCGT_LUNG_T30                  5.293305       2.480892     2245
# TTTGTCATCTTGTATC_EFFUSION_13               4.744932       2.771699     1199
# TTTGTCATCTTTACAC_LUNG_N20                  4.584968       4.901465      834
# TTTGTCATCTTTACAC_LUNG_T25                  4.553877       2.812687      921
# TTTGTCATCTTTAGGG_LUNG_T31                  7.852828       9.398523     5768
#
# [197448 rows x 12 columns]
